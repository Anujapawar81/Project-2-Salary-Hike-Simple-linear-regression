# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv("C:/Users/anuja/OneDrive/Documents/Salary_Data.csv")
print(data)
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes

# %%
data.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
data.tail()
# Out:
#     YearsExperience  Salary
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
data.shape
# Out:
# (30, 2)

# %%
data.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# ## EDA

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,4,1)
plt.hist(data['YearsExperience'])
plt.title("Histogram of 'YearsExperience'")
plt.subplot(2,4,5)
plt.hist(data['Salary'])
plt.title("Histogram of 'Salary'")
# Out:
# Text(0.5, 1.0, "Histogram of 'Salary'")

# %%
plt.figure(figsize=(6,6))
sns.distplot(data['YearsExperience'], kde=True)
plt.title("Density distribution of 'YearsExperience'")
# Out:
# C:\Users\anuja\AppData\Local\Temp\ipykernel_19624\1198523288.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['YearsExperience'], kde=True)
# C:\Users\anuja\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, "Density distribution of 'YearsExperience'")

# %%
plt.figure(figsize=(6,6))
sns.distplot(data['Salary'], kde=True)
plt.title("Density distribution of 'Salary'")
# Out:
# C:\Users\anuja\AppData\Local\Temp\ipykernel_19624\3829224359.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Salary'], kde=True)
# C:\Users\anuja\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, "Density distribution of 'Salary'")

# %%
sns.displot(x=data["Salary"])
plt.title("Distribution of Salary")
print(data["Salary"].skew())
# Out:
# C:\Users\anuja\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.35411967922959153

# %%
## checking for outliers--
plt.figure(figsize=(20,10))
plt.subplot(2,4,1)
sns.boxplot(data['YearsExperience'])
plt.title("Boxplot plot of 'YearsExperience'")
plt.subplot(2,4,2)
sns.boxplot(data['Salary'])
plt.title("box plot of 'Salary'")
# Out:
# Text(0.5, 1.0, "box plot of 'Salary'")

# %% [markdown]
# There is no Outlier in the dataset

# %% [markdown]
# ###  Numerical vs. Numerical data, we can plot the below graphs

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(data=data, x="YearsExperience", y="Salary", hue="YearsExperience", alpha=0.6)
plt.title("Scatter plot")
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %%
plt.figure(figsize=(8,5))
plt.subplot(1,2,1)
sns.lineplot(data=data)
plt.title('Line Plot')
plt.subplot(1,2,2)
sns.lineplot(data=data, x="YearsExperience", y="Salary" ,estimator="sum", color="g")
plt.title("Line plot of YearsExperience, Salary")
# Out:
# C:\Users\anuja\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\anuja\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\anuja\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.xticks(rotation=90,fontsize="medium")
sns.barplot(x="YearsExperience",y="Salary",data=data,color="lightsteelblue")
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
sns.regplot(x="YearsExperience",y="Salary",data=data,color="royalblue")
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %% [markdown]
# ## Checking the Correlation between variables

# %%
plt.figure(figsize=(6,6))
sns.heatmap(data=data, cmap="YlGnBu", annot = True)
# Out:
# <Axes: >

# %%
data.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
sns.heatmap(data.corr(), annot=True)
plt.show()

# %% [markdown]
# it is a high positive correlation.

# %% [markdown]
# ## Predication model of salary hike

# %%
X= data["YearsExperience"].values.reshape(-1,1)
y= data["Salary"].values.reshape(-1,1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
(X_train.shape),(X_test.shape),(y_train.shape),(y_test.shape)
# Out:
# ((24, 1), (6, 1), (24, 1), (6, 1))

# %%
model=LinearRegression()
print(model)
# Out:
# LinearRegression()

# %%
train_model= model.fit(X_train,y_train)
print("Model training is completed")
print(train_model)
# Out:
# Model training is completed
# LinearRegression()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [[9312.57512673]]
# [26780.09915063]

# %%
x1=2.0    #y=mx+b
y=9312.57512673*x1 + 26780.09915063
print("Salary with {} yrs of experience is {}".format(x1,y))
# Out:
# Salary with 2.0 yrs of experience is 45405.249404090006

# %%
y_pred=train_model.predict(X_test)
y_pred
# Out:
# array([[ 40748.96184072],
#        [122699.62295594],
#        [ 64961.65717022],
#        [ 63099.14214487],
#        [115249.56285456],
#        [107799.50275317]])

# %%
y_test
# Out:
# array([[ 37731],
#        [122391],
#        [ 57081],
#        [ 63218],
#        [116969],
#        [109431]], dtype=int64)

# %% [markdown]
# y_test is the real salary of the test set.
# y_pred are the predicted salaries.

# %%
mse = mean_squared_error(y_test,y_pred)
print('mean squared error :',mse)
# Out:
# mean squared error : 12823412.298126562

# %%
r2_score(y_test,y_pred)
# Out:
# 0.988169515729126

# %%
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, model.predict(X_train), color='blue')
plt.title("Salary vs Experience (Training set)") 
plt.xlabel("Years of experience")
plt.ylabel("Salaries")
plt.show()

# %%
plt.scatter(X_test, y_test, color='red') 
plt.plot(X_train, model.predict(X_train), color='blue')
plt.title("Salary vs Experience (Testing set)")
plt.xlabel("Years of experience") 
plt.ylabel("Salaries") 
plt.show()
